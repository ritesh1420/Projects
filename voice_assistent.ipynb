# %%
import pyttsx3 as p
import datetime
import speech_recognition as sr
import wikipedia
#import google
import webbrowser
import os#for file read
import random
engine=p.init()

myname ='fryday'
rate=engine.getProperty('rate')
engine.setProperty('rate', 170)

voices= engine.getProperty('voices')
engine.setProperty('voice', voices[1].id)


def speak(audio):
    engine.say(audio)
    engine.runAndWait()
                                             
def wishme():
    hour=datetime.datetime.now().hour
    if hour>=0 and hour<=12:
        speak('good morning sir')
    elif hour>12 and hour<18:
        speak('good afternooon sir')
    else:
        speak('good evening sir')
    speak(f'i am {myname}, how may i help you')
    
def hearme():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print('listening....')
        audio=r.listen(source)
    try:
        print('recogning')
        query =r.recognize_google(audio,language='en-in')
        print('You Said:',query)
    except Exception:
        print('what sir ,say again please')
        return 'none'
    return query 
  
if __name__ == "__main__":
    wishme()
    while True:
#website opening    
        query=hearme().lower()
        if 'information' or 'what is' in query:
            #query=query.replace('wikipedia',' ')
            speak('searching ......')
            result=wikipedia.summary(query, sentences=4)
            speak('according to wikipedia')
            print(result)
            speak(result)
        elif 'open my instagram' in query:
            speak('opening , please wait sir')
            webbrowser.open('https://www.instagram.com/')
            
        elif 'open google' in query:
            webbrowser.open('www.google.com')
                                
        elif 'open google' in query:
            webbrowser.open('www.google.com') 
        
        elif 'meaning' in query:
         query=query.replace('what is the',' ')    
         search='https://www.google.com/search?q='+query
         webbrowser.open(search)
         
        elif 'google it' in query:   
         query=query.replace('google it',' ')  
         search='https://www.google.com/search?q='+query
         webbrowser.open(search)
         
        elif 'open youtube' in query:   
         speak('opening sir')
         os.startfile('https://www.youtube.com')
       
         
 #system file opening        
        elif 'play music' in query:
           music_dir="C:\\Users\\Ritesh\\Music"
           songs=os.listdir(music_dir)
           speak('playing music')
           song=os.path.join(music_dir, songs[10])
           os.startfile(song)
        elif 'play game recording' in query:
            os.startfile("D:\Assassin's Creed Valhalla\Assassin's Creed Valhalla 2021.07.03 - 22.44.38.09.mp4")
       
        elif ' game recording file' in query:
            speak('sure sir')
            os.startfile("D:\\Assassin's Creed Valhalla")  
            
        elif 'open my game' in query:
          speak('you have only one   game in your  system')
          speak('its a heavy game ,   take    bit time to open ')
          speak(' i am opening , please wait sir')
          os.startfile("D:\\New folder\\Games\Assassins Creed Valhalla\\ACValhalla.exe") 
        elif'open power point' in query:
            speak('opening sir, please wait')
            os.startfile("C:\\ProgramData\\Microsoft\\Windows\\Start Menu\\Programs\\PowerPoint.lnk")
            
        elif 'jupyter notebook' in query:
            speak('opening  sir')
            os.startfile("C:\\ProgramData\\Microsoft\\Windows\\Start Menu\\Programs\\Anaconda3 (64-bit)\Jupyter Notebook (Anaconda3).lnk")
        elif 'compiler' in query:
            speak('opening  sir')
            os.startfile("C:\\ProgramData\\Microsoft\\Windows\\Start Menu\Programs\\Bloodshed Dev-C++\\Dev-C++.lnk")
        elif 'simple notebook' in query:
            os.startfile("C:\\ProgramData\\Microsoft\\Windows\\Start Menu\\Programs\\Accessories\\Notepad.lnk")
        
        
#general query         
        elif 'what is your name'  in query:
            speak('i am friday sir')
        elif 'how are you' in query:
            speak('i am fine sir ,  and  how are you')
        elif 'thank you' in query:
            speak('welcome sir')
        elif 'the time' in query:
            strTime=datetime.datetime.now().strftime("%H:%M:%S")
            speak('sir,the time is')
            speak(strTime)
        elif'kaise ho' in query:
            speak('i can not speak hindi sir')
            speak('so,i will continue,  my conversation in english , please do not mind sir')
            speak('i am fine')
            speak('how are you sir')
        elif 'my best friend' in query:
            speak('ok ')
            os.startfile("C:\\Users\\Ritesh\\Pictures\\th (25).jfif")
            speak(' your friend are monkey sir?')
        elif'look like monkey' in query:
            speak('hahaha')
            speak('but, you are very  smart sir')
            
        elif 'my friend photo again' in query:
            speak('sure sir ')
            os.startfile("C:\\Users\\Ritesh\\Pictures\\th (26).jfif")
            speak('oh no!, early, your friend are looking like, monkey')
            speak('now , they are looking like  donkey')
            speak('it is not fair sir')
            speak('you have added wrong  file directory, to my system')
       
        elif 'who are you' in query:
            speak("i am python based assistant")
            
            
        #else:
         #   search='https://www.google.com/search?q='+query
          #  webbrowser.open(search)
# Out:
# listening....
# recogning
# You Said: what is machine learning
# Machine learning (ML) is a field of inquiry devoted to understanding and building methods that "learn" – that is, methods that leverage data to improve performance on some set of tasks. It is seen as a part of artificial intelligence.
# Machine learning algorithms build a model based on sample data, known as training data, in order to make predictions or decisions without being explicitly programmed to do so. Machine learning algorithms are used in a wide variety of applications, such as in medicine, email filtering, speech recognition, agriculture, and computer vision, where it is difficult or unfeasible to develop conventional algorithms to perform the needed tasks.A subset of machine learning is closely related to computational statistics, which focuses on making predictions using computers, but not all machine learning is statistical learning.
# Exception ignored in: <function BSTR.__del__ at 0x000001AF3D529700>
# ...
